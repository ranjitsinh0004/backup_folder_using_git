# %% [markdown]
# ## eco setup
#
# - use google chrome
# - https://demo.smartsen.se/
# - username : qa1
# - pwd : Abcd@123
# - after log in on ...right click and press inspect element
# - press network
# - reload the page and go on application
# - search smartsense.authToken and its token                 `eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VybmFtZSI6InFhMSIsIm1lbWJlcmlkIjoiMTYyNyIsImV4cHRpbWUiOiIyMDIwLTA4LTE1IDEzOjU1OjE5Ljk5NDc1NCIsImN1clRpbWUiOiIyMDIwLTA4LTE0IDEzOjU1OjE5Ljk5NDc1NCJ9.kTks0PmqcN41SDNf-Q3yPxBtK08rrrBM0ksmJeBhXso`

# %% [markdown]
# ![](auth_token.png)

# %% [markdown]
# ### to seach api
# - refer the following image

# %% [markdown]
# ![](api.png)

# %% [markdown]
# ranjit@ranjit-ThinkPad-X240:~/code$ git init
# Initialized empty Git repository in /home/ranjit/code/.git/
# ranjit@ranjit-ThinkPad-X240:~/code$ sudo touch test1.txt
# [sudo] password for ranjit:
# Sorry, try again.
# [sudo] password for ranjit:
# ranjit@ranjit-ThinkPad-X240:~/code$ touch test1.txt
# ranjit@ranjit-ThinkPad-X240:~/code$ ls
# test1.txt
# ranjit@ranjit-ThinkPad-X240:~/code$ git add .
# ranjit@ranjit-ThinkPad-X240:~/code$ git commit -am "commit1"
# [master (root-commit) e29f30e] commit1
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 test1.txt
# ranjit@ranjit-ThinkPad-X240:~/code$ cd
# ranjit@ranjit-ThinkPad-X240:~$ cd code_backup
# ranjit@ranjit-ThinkPad-X240:~/code_backup$ git init
# Initialized empty Git repository in /home/ranjit/code_backup/.git/
# ranjit@ranjit-ThinkPad-X240:~/code_backup$ git remote add /home/ranjit/code
# usage: git remote add [<options>] <name> <url>
#
#     -f, --fetch           fetch the remote branches
#     --tags                import all tags and associated objects when fetching
#                           or do not fetch any tag at all (--no-tags)
#     -t, --track <branch>  branch(es) to track
#     -m, --master <branch>
#                           master branch
#     --mirror[=<push|fetch>]
#                           set up remote as a mirror to push to or fetch from
#
# ranjit@ranjit-ThinkPad-X240:~/code_backup$ git remote add origin /home/ranjit/code
# ranjit@ranjit-ThinkPad-X240:~/code_backup$ git remote -a
# error: unknown switch `a'
# usage: git remote [-v | --verbose]
#    or: git remote add [-t <branch>] [-m <master>] [-f] [--tags | --no-tags] [--mirror=<fetch|push>] <name> <url>
#    or: git remote rename <old> <new>
#    or: git remote remove <name>
#    or: git remote set-head <name> (-a | --auto | -d | --delete | <branch>)
#    or: git remote [-v | --verbose] show [-n] <name>
#    or: git remote prune [-n | --dry-run] <name>
#    or: git remote [-v | --verbose] update [-p | --prune] [(<group> | <remote>)...]
#    or: git remote set-branches [--add] <name> <branch>...
#    or: git remote get-url [--push] [--all] <name>
#    or: git remote set-url [--push] <name> <newurl> [<oldurl>]
#    or: git remote set-url --add <name> <newurl>
#    or: git remote set-url --delete <name> <url>
#
#     -v, --verbose         be verbose; must be placed before a subcommand
#
# ranjit@ranjit-ThinkPad-X240:~/code_backup$ git remote -v
# origin	/home/ranjit/code (fetch)
# origin	/home/ranjit/code (push)
# ranjit@ranjit-ThinkPad-X240:~/code_backup$ cd
# ranjit@ranjit-ThinkPad-X240:~$ cd code
# ranjit@ranjit-ThinkPad-X240:~/code$ git remote origin /home/ranjit/code_backup
# error: Unknown subcommand: origin
# usage: git remote [-v | --verbose]
#    or: git remote add [-t <branch>] [-m <master>] [-f] [--tags | --no-tags] [--mirror=<fetch|push>] <name> <url>
#    or: git remote rename <old> <new>
#    or: git remote remove <name>
#    or: git remote set-head <name> (-a | --auto | -d | --delete | <branch>)
#    or: git remote [-v | --verbose] show [-n] <name>
#    or: git remote prune [-n | --dry-run] <name>
#    or: git remote [-v | --verbose] update [-p | --prune] [(<group> | <remote>)...]
#    or: git remote set-branches [--add] <name> <branch>...
#    or: git remote get-url [--push] [--all] <name>
#    or: git remote set-url [--push] <name> <newurl> [<oldurl>]
#    or: git remote set-url --add <name> <newurl>
#    or: git remote set-url --delete <name> <url>
#
#     -v, --verbose         be verbose; must be placed before a subcommand
#
# ranjit@ranjit-ThinkPad-X240:~/code$ git remote add origin /home/ranjit/code_backup
# ranjit@ranjit-ThinkPad-X240:~/code$ git remote -v
# origin	/home/ranjit/code_backup (fetch)
# origin	/home/ranjit/code_backup (push)
# ranjit@ranjit-ThinkPad-X240:~/code$ git push origin master
# Counting objects: 3, done.
# Writing objects: 100% (3/3), 216 bytes | 216.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# remote: error: refusing to update checked out branch: refs/heads/master
# remote: error: By default, updating the current branch in a non-bare repository
# remote: is denied, because it will make the index and work tree inconsistent
# remote: with what you pushed, and will require 'git reset --hard' to match
# remote: the work tree to HEAD.
# remote:
# remote: You can set the 'receive.denyCurrentBranch' configuration variable
# remote: to 'ignore' or 'warn' in the remote repository to allow pushing into
# remote: its current branch; however, this is not recommended unless you
# remote: arranged to update its work tree to match what you pushed in some
# remote: other way.
# remote:
# remote: To squelch this message and still keep the default behaviour, set
# remote: 'receive.denyCurrentBranch' configuration variable to 'refuse'.
# To /home/ranjit/code_backup
#  ! [remote rejected] master -> master (branch is currently checked out)
# error: failed to push some refs to '/home/ranjit/code_backup'
# ranjit@ranjit-ThinkPad-X240:~/code$ git status
# On branch master
# nothing to commit, working tree clean
# ranjit@ranjit-ThinkPad-X240:~/code$ ls
# test1.txt
# ranjit@ranjit-ThinkPad-X240:~/code$ git branch new_branch
# ranjit@ranjit-ThinkPad-X240:~/code$ git checkout new_branch
#         Switched to branch 'new_branch'
# ranjit@ranjit-ThinkPad-X240:~/code$ ls
# test1.txt
# ranjit@ranjit-ThinkPad-X240:~/code$ git push origin master
#         Counting objects: 3, done.
#         Writing objects: 100% (3/3), 216 bytes | 216.00 KiB/s, done.
#         Total 3 (delta 0), reused 0 (delta 0)
#         remote: error: refusing to update checked out branch: refs/heads/master
#         remote: error: By default, updating the current branch in a non-bare repository
#         remote: is denied, because it will make the index and work tree inconsistent
#         remote: with what you pushed, and will require 'git reset --hard' to match
#         remote: the work tree to HEAD.
#         remote:
#         remote: You can set the 'receive.denyCurrentBranch' configuration variable
#         remote: to 'ignore' or 'warn' in the remote repository to allow pushing into
#         remote: its current branch; however, this is not recommended unless you
#         remote: arranged to update its work tree to match what you pushed in some
#         remote: other way.
#         remote:
#         remote: To squelch this message and still keep the default behaviour, set
#         remote: 'receive.denyCurrentBranch' configuration variable to 'refuse'.
#         To /home/ranjit/code_backup
#         ! [remote rejected] master -> master (branch is currently checked out)
#         error: failed to push some refs to '/home/ranjit/code_backup'
#         ranjit@ranjit-ThinkPad-X240:~/code$ git config --bool core.bare true
#         ranjit@ranjit-ThinkPad-X240:~/code$ git push origin master
#         Counting objects: 3, done.
#         Writing objects: 100% (3/3), 216 bytes | 216.00 KiB/s, done.
#         Total 3 (delta 0), reused 0 (delta 0)
#         remote: error: refusing to update checked out branch: refs/heads/master
#         remote: error: By default, updating the current branch in a non-bare repository
#         remote: is denied, because it will make the index and work tree inconsistent
#         remote: with what you pushed, and will require 'git reset --hard' to match
#         remote: the work tree to HEAD.
#         remote:
#         remote: You can set the 'receive.denyCurrentBranch' configuration variable
#         remote: to 'ignore' or 'warn' in the remote repository to allow pushing into
#         remote: its current branch; however, this is not recommended unless you
#         remote: arranged to update its work tree to match what you pushed in some
#         remote: other way.
#         remote:
#         remote: To squelch this message and still keep the default behaviour, set
#         remote: 'receive.denyCurrentBranch' configuration variable to 'refuse'.
#         To /home/ranjit/code_backup
#         ! [remote rejected] master -> master (branch is currently checked out)
#         error: failed to push some refs to '/home/ranjit/code_backup'
# - ranjit@ranjit-ThinkPad-X240:~/code$ git config --bool core.bare false
# - ranjit@ranjit-ThinkPad-X240:~/code$ cd
# - ranjit@ranjit-ThinkPad-X240:~$ cd code_backup
#
# -  ranjit@ranjit-ThinkPad-X240:~/code_backup$ `git config --bool core.bare true`
# - ranjit@ranjit-ThinkPad-X240:~/code_backup$ cd
# - ranjit@ranjit-ThinkPad-X240:~$ cd code
# - ranjit@ranjit-ThinkPad-X240:~/code$ git push origin master
#         Counting objects: 3, done.
#         Writing objects: 100% (3/3), 216 bytes | 216.00 KiB/s, done.
#         Total 3 (delta 0), reused 0 (delta 0)
#         To /home/ranjit/code_backup
#         * [new branch]      master -> master
# ranjit@ranjit-ThinkPad-X240:~/code$
